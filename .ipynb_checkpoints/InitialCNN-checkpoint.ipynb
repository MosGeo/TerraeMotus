# %% [markdown]
# # Introduction
# We will attempt to use convonlutional neural network on the dataset. This is the initial attempt so we will apply it on a very small dataset on the raw data in one channel (vertical). First, let us import the required packages including tensorflow.

# %%
#import tensorflow as tf;
import matplotlib.pyplot as plt
import numpy as np

from obspy.taup import TauPyModel
from obspy.geodetics import gps2dist_azimuth, kilometer2degrees
from obspy import UTCDateTime
from obspy.clients.fdsn import Client



import pickle

# %% [markdown]
# Let us define a retrieval function to be used for getting the data

# %%
def getEvents(clientName, networkName,  stationName, startTime, endTime, minMagnitude, maxRadius):
    '''
    Get the events
    '''
    # Find the possible earthquakes and put them in a catalog
    client = Client(clientName)
    inventory = client.get_stations(network=networkName, station=stationName)
    station = inventory[0][0]
    cat = client.get_events(starttime=startTime, endtime=endTime, minmagnitude=minMagnitude, latitude=station.latitude, longitude=station.longitude, maxradius=maxRadius)
    
    return cat

def getStreams(clientName, networkName,  stationName, cat, timeBefore, timeAfter):
    '''
    Get the streams for the events
    '''
    client = Client(clientName)
    inventory = client.get_stations(network=networkName, station=stationName)
    station = inventory[0][0]
    
    # Get the stream for each event
    model = TauPyModel(model="iasp91")
    
    nEvents = len(cat)
    print("Will analyze " + str(nEvents) + " events")
    stList = []
    for i in range(0, nEvents):
        try:
            print("Analyzing event " + str(i))
            event = cat[i]
            origin = event.origins[0]
            distance, _, _ = gps2dist_azimuth(origin.latitude, origin.longitude, station.latitude, station.longitude)
            distance = kilometer2degrees(distance / 1e3)
            arrivals = model.get_travel_times(origin.depth / 1e3, distance)
            traveltime = arrivals[0].time
            arrival_time = origin.time + traveltime

            # Get the earthquake signal and store its needed information
            st = client.get_waveforms(network=networkName, station=stationName, location="00", channel=channelName, starttime=arrival_time-timeBefore, endtime=arrival_time+timeAfter)
            stList.append(st)
        except:
            print("Could not get stream " + str(i))
    return stList

def getRandomStreams(clientName, networkName,  stationName, timeBefore, timeAfter, starttime=startTime, endtime=endTime, nEvents = 1):
    '''
    Get the streams for the events
    '''
    client = Client(clientName)

    
    print("Will analyze " + str(nEvents) + " events")
    stList = []
    for i in range(0, nEvents):
        try:
            print("Analyzing event " + str(i))
            arrival_time = startTime + (endTime - startTime) * np.random.random()
            st = client.get_waveforms(network=networkName, station=stationName, location="00", channel=channelName, starttime=arrival_time-timeBefore, endtime=arrival_time+timeAfter)
            stList.append(st)
        except:
            i = i-1
            print("Could not get stream " + str(i))
    return stList

# %% [markdown]
# let us make a function that save and load the list of seismogram. It is a list of objects so we have to use the package pickle which is included in python by default.

# %%
def saveList(listToSave, fileName = 'SavedList.dat'):
    '''
    Save a list into a file.
    '''
    pickle.dump( listToSave, open(fileName, "wb" ))


def loadList(fileName):
    '''
    Load a list from a file
    '''
    loadedList = pickle.load( open( fileName, "rb" ))
    return loadedList

# %% [markdown]
# Finally, we define a function to extract the data to numpy format for further analysis.

# %%
def st2numpy(st):
    '''
    Retrive import information from the seismogram
    '''
    trace = st.pop()
    data = trace.data
    time = trace.times('matplotlib')
    return time, data

def stList2numpy(stList , label=1):
    nSt = len(stList)
    timeList = []
    dataList = []
    labelList = []
    
    for i in range(0, nSt):
        time, data = st2numpy(stList[i])
        timeList.append(time)
        dataList.append(data)
        labelList.append(label)
    
    timeArray = np.asarray(timeList).T;
    dataArray = np.asarray(dataList).T;
    labelArray = np.asarray(labelList).T;
    labelArray = labelArray[:,np.newaxis]

    return timeArray, dataArray, labelArray

# %% [markdown]
# # Building the dataset
# Now, let us retrieve the dataset and save it.

# %%
networkName      = "BK"
stationName      = "PKD"
clientName       = "NCEDC"
startTime        = UTCDateTime("2010-01-01")
endTime          = UTCDateTime("2018-05-13")
maxRadius        = .5 # angle
minMagnitude     = 2
channelName      = "LHZ" #vertical

timeAfter  = -60;      # seconds
timeBefore = 60+1024; # seconds
pos2neg = 1;

cat  = getEvents(clientName, networkName,  stationName, startTime, endTime, minMagnitude, maxRadius)
len(cat)
# Out:
# 741

# %%
stListPositives = getStreams(clientName, networkName,  stationName, cat, timeBefore, timeAfter)

nNegatives = int(pos2neg * len(stListPositives))
stListNegatives = getRandomStreams(clientName, networkName,  stationName, timeBefore, timeAfter, startTime, endTime, nNegatives)

saveList(stListPositives, fileName = 'PositivesList2.dat')
saveList(stListNegatives, fileName = 'NegativesList2.dat')
# Out:
# Will analyze 741 events
# Analyzing event 0
# Analyzing event 1
# Analyzing event 2
# Analyzing event 3
# Analyzing event 4
# Analyzing event 5
# Analyzing event 6
# Analyzing event 7
# Analyzing event 8
# Analyzing event 9
# Analyzing event 10
# Analyzing event 11
# Analyzing event 12
# Analyzing event 13
# Analyzing event 14
# Analyzing event 15
# Analyzing event 16
# Analyzing event 17
# Analyzing event 18
# Analyzing event 19
# Analyzing event 20
# Analyzing event 21
# Analyzing event 22
# Analyzing event 23
# Analyzing event 24
# Analyzing event 25
# Analyzing event 26
# Analyzing event 27
# Analyzing event 28
# Analyzing event 29
# Analyzing event 30
# Analyzing event 31
# Analyzing event 32
# Analyzing event 33
# Analyzing event 34
# Analyzing event 35
# Analyzing event 36
# Analyzing event 37
# Analyzing event 38
# Analyzing event 39
# Analyzing event 40
# Analyzing event 41
# Analyzing event 42
# Analyzing event 43
# Analyzing event 44
# Analyzing event 45
# Analyzing event 46
# Analyzing event 47
# Analyzing event 48
# Analyzing event 49
# Analyzing event 50
# Analyzing event 51
# Analyzing event 52
# Analyzing event 53
# Analyzing event 54
# Analyzing event 55
# Analyzing event 56
# Analyzing event 57
# Analyzing event 58
# Analyzing event 59
# Analyzing event 60
# Analyzing event 61
# Analyzing event 62
# Analyzing event 63
# Analyzing event 64
# Analyzing event 65
# Analyzing event 66
# Analyzing event 67
# Analyzing event 68
# Analyzing event 69
# Analyzing event 70
# Analyzing event 71
# Analyzing event 72
# Analyzing event 73
# Analyzing event 74
# Analyzing event 75
# Analyzing event 76
# Analyzing event 77
# Analyzing event 78
# Analyzing event 79
# Analyzing event 80
# Analyzing event 81
# Analyzing event 82
# Analyzing event 83
# Analyzing event 84
# Analyzing event 85
# Analyzing event 86
# Analyzing event 87
# Analyzing event 88
# Analyzing event 89
# Analyzing event 90
# Analyzing event 91
# Analyzing event 92
# Analyzing event 93
# Could not get stream 93
# Analyzing event 94
# Analyzing event 95
# Analyzing event 96
# Analyzing event 97
# Analyzing event 98
# Analyzing event 99
# Analyzing event 100
# Analyzing event 101
# Analyzing event 102
# Analyzing event 103
# Analyzing event 104
# Analyzing event 105
# Analyzing event 106
# Analyzing event 107
# Analyzing event 108
# Analyzing event 109
# Analyzing event 110
# Analyzing event 111
# Analyzing event 112
# Analyzing event 113
# Analyzing event 114
# Could not get stream 114
# Analyzing event 115
# Analyzing event 116
# Analyzing event 117
# Analyzing event 118
# Analyzing event 119
# Analyzing event 120
# Analyzing event 121
# Analyzing event 122
# Analyzing event 123
# Analyzing event 124
# Analyzing event 125
# Analyzing event 126
# Analyzing event 127
# Analyzing event 128
# Analyzing event 129
# Analyzing event 130
# Analyzing event 131
# Analyzing event 132
# Analyzing event 133
# Analyzing event 134
# Analyzing event 135
# Analyzing event 136
# Analyzing event 137
# Analyzing event 138
# Analyzing event 139
# Analyzing event 140
# Analyzing event 141
# Analyzing event 142
# Analyzing event 143
# Analyzing event 144
# Analyzing event 145
# Analyzing event 146
# Analyzing event 147
# Analyzing event 148
# Analyzing event 149
# Analyzing event 150
# Analyzing event 151
# Analyzing event 152
# Analyzing event 153
# Analyzing event 154
# Analyzing event 155
# Analyzing event 156
# Analyzing event 157
# Analyzing event 158
# Analyzing event 159
# Analyzing event 160
# Analyzing event 161
# Analyzing event 162
# Analyzing event 163
# Analyzing event 164
# Analyzing event 165
# Analyzing event 166
# Analyzing event 167
# Analyzing event 168
# Analyzing event 169
# Analyzing event 170
# Analyzing event 171
# Analyzing event 172
# Analyzing event 173
# Analyzing event 174
# Analyzing event 175
# Analyzing event 176
# Analyzing event 177
# Analyzing event 178
# Analyzing event 179
# Analyzing event 180
# Analyzing event 181
# Analyzing event 182
# Analyzing event 183
# Analyzing event 184
# Analyzing event 185
# Analyzing event 186
# Analyzing event 187
# Analyzing event 188
# Analyzing event 189
# Analyzing event 190
# Analyzing event 191
# Analyzing event 192
# Analyzing event 193
# Analyzing event 194
# Analyzing event 195
# Analyzing event 196
# Analyzing event 197
# Analyzing event 198
# Analyzing event 199
# Analyzing event 200
# Analyzing event 201
# Analyzing event 202
# Analyzing event 203
# Analyzing event 204
# Analyzing event 205
# Analyzing event 206
# Analyzing event 207
# Analyzing event 208
# Analyzing event 209
# Analyzing event 210
# Analyzing event 211
# Analyzing event 212
# Analyzing event 213
# Analyzing event 214
# Analyzing event 215
# Analyzing event 216
# Analyzing event 217
# Analyzing event 218
# Analyzing event 219
# Analyzing event 220
# Analyzing event 221
# Analyzing event 222
# Analyzing event 223
# Analyzing event 224
# Analyzing event 225
# Analyzing event 226
# Analyzing event 227
# Analyzing event 228
# Analyzing event 229
# Analyzing event 230
# Analyzing event 231
# Analyzing event 232
# Analyzing event 233
# Analyzing event 234
# Analyzing event 235
# Analyzing event 236
# Analyzing event 237
# Analyzing event 238
# Could not get stream 238
# Analyzing event 239
# Analyzing event 240
# Analyzing event 241
# Analyzing event 242
# Analyzing event 243
# Analyzing event 244
# Analyzing event 245
# Analyzing event 246
# Analyzing event 247
# Analyzing event 248
# Analyzing event 249
# Analyzing event 250
# Analyzing event 251
# Analyzing event 252
# Analyzing event 253
# Analyzing event 254
# Analyzing event 255
# Analyzing event 256
# Analyzing event 257
# Analyzing event 258
# Analyzing event 259
# Analyzing event 260
# Analyzing event 261
# Analyzing event 262
# Analyzing event 263
# Analyzing event 264
# Analyzing event 265
# Analyzing event 266
# Analyzing event 267
# Analyzing event 268
# Analyzing event 269
# Analyzing event 270
# Analyzing event 271
# Analyzing event 272
# Analyzing event 273
# Analyzing event 274
# Analyzing event 275
# Analyzing event 276
# Analyzing event 277
# Analyzing event 278
# Analyzing event 279
# Analyzing event 280
# Analyzing event 281
# Analyzing event 282
# Analyzing event 283
# Analyzing event 284
# Analyzing event 285
# Analyzing event 286
# Analyzing event 287
# Analyzing event 288
# Analyzing event 289
# Analyzing event 290
# Analyzing event 291
# Analyzing event 292
# Analyzing event 293
# Analyzing event 294
# Analyzing event 295
# Analyzing event 296
# Analyzing event 297
# Analyzing event 298
# Analyzing event 299
# Analyzing event 300
# Analyzing event 301
# Analyzing event 302
# Analyzing event 303
# Could not get stream 303
# Analyzing event 304
# Analyzing event 305
# Analyzing event 306
# Analyzing event 307
# Analyzing event 308
# Analyzing event 309
# Analyzing event 310
# Analyzing event 311
# Analyzing event 312
# Analyzing event 313
# Analyzing event 314
# Analyzing event 315
# Analyzing event 316
# Analyzing event 317
# Could not get stream 317
# Analyzing event 318
# Could not get stream 318
# Analyzing event 319
# Could not get stream 319
# Analyzing event 320
# Could not get stream 320
# Analyzing event 321
# Analyzing event 322
# Analyzing event 323
# Analyzing event 324
# Analyzing event 325
# Analyzing event 326
# Analyzing event 327
# Analyzing event 328
# Analyzing event 329
# Analyzing event 330
# Analyzing event 331
# Analyzing event 332
# Analyzing event 333
# Analyzing event 334
# Analyzing event 335
# Analyzing event 336
# Analyzing event 337
# Analyzing event 338
# Analyzing event 339
# Analyzing event 340
# Analyzing event 341
# Analyzing event 342
# Analyzing event 343
# Analyzing event 344
# Analyzing event 345
# Analyzing event 346
# Analyzing event 347
# Analyzing event 348
# Analyzing event 349
# Analyzing event 350
# Analyzing event 351
# Analyzing event 352
# Analyzing event 353
# Analyzing event 354
# Analyzing event 355
# Analyzing event 356
# Analyzing event 357
# Analyzing event 358
# Analyzing event 359
# Analyzing event 360
# Analyzing event 361
# Analyzing event 362
# Analyzing event 363
# Analyzing event 364
# Analyzing event 365
# Analyzing event 366
# Analyzing event 367
# Analyzing event 368
# Analyzing event 369
# Analyzing event 370
# Analyzing event 371
# Analyzing event 372
# Analyzing event 373
# Analyzing event 374
# Analyzing event 375
# Analyzing event 376
# Analyzing event 377
# Analyzing event 378
# Analyzing event 379
# Analyzing event 380
# Analyzing event 381
# Analyzing event 382
# Analyzing event 383
# Analyzing event 384
# Analyzing event 385
# Analyzing event 386
# Analyzing event 387
# Analyzing event 388
# Analyzing event 389
# Analyzing event 390
# Analyzing event 391
# Analyzing event 392
# Analyzing event 393
# Analyzing event 394
# Analyzing event 395
# Analyzing event 396
# Analyzing event 397
# Analyzing event 398
# Analyzing event 399
# Analyzing event 400
# Analyzing event 401
# Analyzing event 402
# Analyzing event 403
# Analyzing event 404
# Analyzing event 405
# Analyzing event 406
# Analyzing event 407
# Analyzing event 408
# Analyzing event 409
# Analyzing event 410
# Analyzing event 411
# Analyzing event 412
# Analyzing event 413
# Analyzing event 414
# Analyzing event 415
# Analyzing event 416
# Analyzing event 417
# Analyzing event 418
# Analyzing event 419
# Analyzing event 420
# Analyzing event 421
# Analyzing event 422
# Analyzing event 423
# Analyzing event 424
# Analyzing event 425
# Analyzing event 426
# Analyzing event 427
# Analyzing event 428
# Analyzing event 429
# Analyzing event 430
# Analyzing event 431
# Analyzing event 432
# Analyzing event 433
# Analyzing event 434
# Analyzing event 435
# Analyzing event 436
# Analyzing event 437
# Analyzing event 438
# Analyzing event 439
# Analyzing event 440
# Analyzing event 441
# Analyzing event 442
# Analyzing event 443
# Analyzing event 444
# Analyzing event 445
# Analyzing event 446
# Analyzing event 447
# Analyzing event 448
# Analyzing event 449
# Analyzing event 450
# Analyzing event 451
# Analyzing event 452
# Analyzing event 453
# Analyzing event 454
# Analyzing event 455
# Analyzing event 456
# Analyzing event 457
# Analyzing event 458
# Analyzing event 459
# Analyzing event 460
# Analyzing event 461
# Analyzing event 462
# Analyzing event 463
# Analyzing event 464
# Analyzing event 465
# Analyzing event 466
# Analyzing event 467
# Analyzing event 468
# Analyzing event 469
# Analyzing event 470
# Analyzing event 471
# Analyzing event 472
# Analyzing event 473
# Analyzing event 474
# Analyzing event 475
# Analyzing event 476
# Analyzing event 477
# Analyzing event 478
# Analyzing event 479
# Analyzing event 480
# Analyzing event 481
# Analyzing event 482
# Analyzing event 483
# Analyzing event 484
# Analyzing event 485
# Analyzing event 486
# Analyzing event 487
# Analyzing event 488
# Analyzing event 489
# Analyzing event 490
# Analyzing event 491
# Analyzing event 492
# Analyzing event 493
# Analyzing event 494
# Analyzing event 495
# Analyzing event 496
# Analyzing event 497
# Analyzing event 498
# Analyzing event 499
# Analyzing event 500
# Analyzing event 501
# Analyzing event 502
# Analyzing event 503
# Analyzing event 504
# Analyzing event 505
# Analyzing event 506
# Analyzing event 507
# Analyzing event 508
# Analyzing event 509
# Analyzing event 510
# Analyzing event 511
# Analyzing event 512
# Analyzing event 513
# Analyzing event 514
# Analyzing event 515
# Analyzing event 516
# Analyzing event 517
# Analyzing event 518
# Analyzing event 519
# Analyzing event 520
# Analyzing event 521
# Analyzing event 522
# Analyzing event 523
# Analyzing event 524
# Analyzing event 525
# Analyzing event 526
# Analyzing event 527
# Analyzing event 528
# Analyzing event 529
# Analyzing event 530
# Analyzing event 531
# Analyzing event 532
# Analyzing event 533
# Analyzing event 534
# Analyzing event 535
# Analyzing event 536
# Analyzing event 537
# Analyzing event 538
# Analyzing event 539
# Analyzing event 540
# Analyzing event 541
# Analyzing event 542
# Analyzing event 543
# Analyzing event 544
# Analyzing event 545
# Analyzing event 546
# Analyzing event 547
# Analyzing event 548
# Analyzing event 549
# Analyzing event 550
# Analyzing event 551
# Analyzing event 552
# Analyzing event 553
# Analyzing event 554
# Analyzing event 555
# Analyzing event 556
# Analyzing event 557
# Analyzing event 558
# Analyzing event 559
# Analyzing event 560
# Analyzing event 561
# Analyzing event 562
# Analyzing event 563
# Analyzing event 564
# Could not get stream 564
# Analyzing event 565
# Analyzing event 566
# Analyzing event 567
# Analyzing event 568
# Analyzing event 569
# Analyzing event 570
# Analyzing event 571
# Analyzing event 572
# Analyzing event 573
# Analyzing event 574
# Analyzing event 575
# Analyzing event 576
# Analyzing event 577
# Analyzing event 578
# Analyzing event 579
# Analyzing event 580
# Analyzing event 581
# Analyzing event 582
# Analyzing event 583
# Analyzing event 584
# Analyzing event 585
# Analyzing event 586
# Analyzing event 587
# Analyzing event 588
# Analyzing event 589
# Analyzing event 590
# Analyzing event 591
# Analyzing event 592
# Analyzing event 593
# Analyzing event 594
# Analyzing event 595
# Analyzing event 596
# Analyzing event 597
# Analyzing event 598
# Analyzing event 599
# Analyzing event 600
# Analyzing event 601
# Analyzing event 602
# Analyzing event 603
# Analyzing event 604
# Analyzing event 605
# Analyzing event 606
# Analyzing event 607
# Analyzing event 608
# Analyzing event 609
# Analyzing event 610
# Analyzing event 611
# Analyzing event 612
# Analyzing event 613
# Analyzing event 614
# Analyzing event 615
# Analyzing event 616
# Analyzing event 617
# Analyzing event 618
# Analyzing event 619
# Analyzing event 620
# Analyzing event 621
# Analyzing event 622
# Analyzing event 623
# Analyzing event 624
# Analyzing event 625
# Analyzing event 626
# Analyzing event 627
# Analyzing event 628
# Analyzing event 629
# Analyzing event 630
# Analyzing event 631
# Analyzing event 632
# Analyzing event 633
# Analyzing event 634
# Analyzing event 635
# Analyzing event 636
# Analyzing event 637
# Analyzing event 638
# Analyzing event 639
# Analyzing event 640
# Analyzing event 641
# Analyzing event 642
# Analyzing event 643
# Analyzing event 644
# Analyzing event 645
# Analyzing event 646
# Analyzing event 647
# Analyzing event 648
# Analyzing event 649
# Analyzing event 650
# Analyzing event 651
# Analyzing event 652
# Analyzing event 653
# Analyzing event 654
# Analyzing event 655
# Analyzing event 656
# Analyzing event 657
# Analyzing event 658
# Analyzing event 659
# Analyzing event 660
# Analyzing event 661
# Analyzing event 662
# Analyzing event 663
# Analyzing event 664
# Analyzing event 665
# Analyzing event 666
# Analyzing event 667
# Analyzing event 668
# Analyzing event 669
# Analyzing event 670
# Analyzing event 671
# Analyzing event 672
# Analyzing event 673
# Analyzing event 674
# Analyzing event 675
# Analyzing event 676
# Analyzing event 677
# Analyzing event 678
# Analyzing event 679
# Analyzing event 680
# Analyzing event 681
# Analyzing event 682
# Analyzing event 683
# Analyzing event 684
# Analyzing event 685
# Analyzing event 686
# Analyzing event 687
# Analyzing event 688
# Analyzing event 689
# Analyzing event 690
# Analyzing event 691
# Analyzing event 692
# Analyzing event 693
# Analyzing event 694
# Analyzing event 695
# Analyzing event 696
# Analyzing event 697
# Could not get stream 697
# Analyzing event 698
# Analyzing event 699
# Analyzing event 700
# Analyzing event 701
# Analyzing event 702
# Analyzing event 703
# Analyzing event 704
# Analyzing event 705
# Analyzing event 706
# Analyzing event 707
# Analyzing event 708
# Could not get stream 708
# Analyzing event 709
# Could not get stream 709
# Analyzing event 710
# Could not get stream 710
# Analyzing event 711
# Could not get stream 711
# Analyzing event 712
# Could not get stream 712
# Analyzing event 713
# Could not get stream 713
# Analyzing event 714
# Could not get stream 714
# Analyzing event 715
# Could not get stream 715
# Analyzing event 716
# Could not get stream 716
# Analyzing event 717
# Could not get stream 717
# Analyzing event 718
# Could not get stream 718
# Analyzing event 719
# Could not get stream 719
# Analyzing event 720
# Could not get stream 720
# Analyzing event 721
# Could not get stream 721
# Analyzing event 722
# Could not get stream 722
# Analyzing event 723
# Could not get stream 723
# Analyzing event 724
# Could not get stream 724
# Analyzing event 725
# Could not get stream 725
# Analyzing event 726
# Could not get stream 726
# Analyzing event 727
# Could not get stream 727
# Analyzing event 728
# Could not get stream 728
# Analyzing event 729
# Could not get stream 729
# Analyzing event 730
# Could not get stream 730
# Analyzing event 731
# Could not get stream 731
# Analyzing event 732
# Could not get stream 732
# Analyzing event 733
# Could not get stream 733
# Analyzing event 734
# Could not get stream 734
# Analyzing event 735
# Could not get stream 735
# Analyzing event 736
# Could not get stream 736
# Analyzing event 737
# Could not get stream 737
# Analyzing event 738
# Could not get stream 738
# Analyzing event 739
# Could not get stream 739
# Analyzing event 740
# Could not get stream 740
# Will analyze 698 events
# Analyzing event 0
# Analyzing event 1
# Analyzing event 2
# Analyzing event 3
# Analyzing event 4
# Analyzing event 5
# Analyzing event 6
# Analyzing event 7
# Analyzing event 8
# Analyzing event 9
# Analyzing event 10
# Analyzing event 11
# Analyzing event 12
# Analyzing event 13
# Analyzing event 14
# Analyzing event 15
# Analyzing event 16
# Analyzing event 17
# Analyzing event 18
# Analyzing event 19
# Analyzing event 20
# Analyzing event 21
# Analyzing event 22
# Analyzing event 23
# Analyzing event 24
# Analyzing event 25
# Analyzing event 26
# Analyzing event 27
# Analyzing event 28
# Analyzing event 29
# Analyzing event 30
# Analyzing event 31
# Analyzing event 32
# Analyzing event 33
# Analyzing event 34
# Analyzing event 35
# Analyzing event 36
# Analyzing event 37
# Analyzing event 38
# Analyzing event 39
# Analyzing event 40
# Analyzing event 41
# Analyzing event 42
# Analyzing event 43
# Analyzing event 44
# Analyzing event 45
# Analyzing event 46
# Analyzing event 47
# Analyzing event 48
# Analyzing event 49
# Analyzing event 50
# Analyzing event 51
# Analyzing event 52
# Analyzing event 53
# Analyzing event 54
# Analyzing event 55
# Analyzing event 56
# Analyzing event 57
# Analyzing event 58
# Analyzing event 59
# Analyzing event 60
# Analyzing event 61
# Analyzing event 62
# Analyzing event 63
# Analyzing event 64
# Analyzing event 65
# Analyzing event 66
# Analyzing event 67
# Analyzing event 68
# Analyzing event 69
# Analyzing event 70
# Analyzing event 71
# Could not get stream 71
# Analyzing event 72
# Analyzing event 73
# Analyzing event 74
# Analyzing event 75
# Analyzing event 76
# Analyzing event 77
# Analyzing event 78
# Analyzing event 79
# Analyzing event 80
# Analyzing event 81
# Analyzing event 82
# Analyzing event 83
# Analyzing event 84
# Analyzing event 85
# Analyzing event 86
# Analyzing event 87
# Analyzing event 88
# Analyzing event 89
# Analyzing event 90
# Analyzing event 91
# Analyzing event 92
# Analyzing event 93
# Analyzing event 94
# Analyzing event 95
# Analyzing event 96
# Analyzing event 97
# Analyzing event 98
# Analyzing event 99
# Analyzing event 100
# Analyzing event 101
# Analyzing event 102
# Analyzing event 103
# Analyzing event 104
# Analyzing event 105
# Analyzing event 106
# Analyzing event 107
# Analyzing event 108
# Analyzing event 109
# Analyzing event 110
# Analyzing event 111
# Analyzing event 112
# Analyzing event 113
# Analyzing event 114
# Analyzing event 115
# Analyzing event 116
# Analyzing event 117
# Analyzing event 118
# Analyzing event 119
# Analyzing event 120
# Analyzing event 121
# Analyzing event 122
# Analyzing event 123
# Analyzing event 124
# Analyzing event 125
# Analyzing event 126
# Analyzing event 127
# Analyzing event 128
# Analyzing event 129
# Analyzing event 130
# Analyzing event 131
# Analyzing event 132
# Analyzing event 133
# Analyzing event 134
# Analyzing event 135
# Analyzing event 136
# Analyzing event 137
# Analyzing event 138
# Analyzing event 139
# Analyzing event 140
# Analyzing event 141
# Analyzing event 142
# Analyzing event 143
# Analyzing event 144
# Could not get stream 144
# Analyzing event 145
# Analyzing event 146
# Analyzing event 147
# Analyzing event 148
# Analyzing event 149
# Analyzing event 150
# Analyzing event 151
# Analyzing event 152
# Analyzing event 153
# Analyzing event 154
# Analyzing event 155
# Analyzing event 156
# Analyzing event 157
# Analyzing event 158
# Analyzing event 159
# Analyzing event 160
# Analyzing event 161
# Analyzing event 162
# Analyzing event 163
# Analyzing event 164
# Analyzing event 165
# Analyzing event 166
# Analyzing event 167
# Analyzing event 168
# Analyzing event 169
# Analyzing event 170
# Analyzing event 171
# Analyzing event 172
# Analyzing event 173
# Analyzing event 174
# Analyzing event 175
# Analyzing event 176
# Analyzing event 177
# Analyzing event 178
# Analyzing event 179
# Analyzing event 180
# Analyzing event 181
# Analyzing event 182
# Analyzing event 183
# Analyzing event 184
# Analyzing event 185
# Analyzing event 186
# Analyzing event 187
# Analyzing event 188
# Analyzing event 189
# Analyzing event 190
# Analyzing event 191
# Analyzing event 192
# Analyzing event 193
# Analyzing event 194
# Could not get stream 194
# Analyzing event 195
# Analyzing event 196
# Analyzing event 197
# Analyzing event 198
# Analyzing event 199
# Analyzing event 200
# Analyzing event 201
# Analyzing event 202
# Analyzing event 203
# Analyzing event 204
# Analyzing event 205
# Analyzing event 206
# Analyzing event 207
# Analyzing event 208
# Analyzing event 209
# Analyzing event 210
# Analyzing event 211
# Could not get stream 211
# Analyzing event 212
# Analyzing event 213
# Analyzing event 214
# Analyzing event 215
# Analyzing event 216
# Analyzing event 217
# Could not get stream 217
# Analyzing event 218
# Analyzing event 219
# Analyzing event 220
# Analyzing event 221
# Analyzing event 222
# Analyzing event 223
# Analyzing event 224
# Analyzing event 225
# Analyzing event 226
# Analyzing event 227
# Analyzing event 228
# Analyzing event 229
# Analyzing event 230
# Analyzing event 231
# Analyzing event 232
# Analyzing event 233
# Analyzing event 234
# Analyzing event 235
# Analyzing event 236
# Analyzing event 237
# Analyzing event 238
# Analyzing event 239
# Analyzing event 240
# Analyzing event 241
# Analyzing event 242
# Analyzing event 243
# Analyzing event 244
# Analyzing event 245
# Analyzing event 246
# Analyzing event 247
# Analyzing event 248
# Analyzing event 249
# Could not get stream 249
# Analyzing event 250
# Analyzing event 251
# Analyzing event 252
# Analyzing event 253
# Analyzing event 254
# Analyzing event 255
# Analyzing event 256
# Analyzing event 257
# Analyzing event 258
# Analyzing event 259
# Analyzing event 260
# Analyzing event 261
# Analyzing event 262
# Analyzing event 263
# Analyzing event 264
# Analyzing event 265
# Analyzing event 266
# Analyzing event 267
# Analyzing event 268
# Analyzing event 269
# Analyzing event 270
# Analyzing event 271
# Analyzing event 272
# Analyzing event 273
# Analyzing event 274
# Analyzing event 275
# Analyzing event 276
# Analyzing event 277
# Analyzing event 278
# Analyzing event 279
# Analyzing event 280
# Analyzing event 281
# Analyzing event 282
# Analyzing event 283
# Could not get stream 283
# Analyzing event 284
# Analyzing event 285
# Analyzing event 286
# Analyzing event 287
# Analyzing event 288
# Analyzing event 289
# Analyzing event 290
# Analyzing event 291
# Analyzing event 292
# Analyzing event 293
# Analyzing event 294
# Analyzing event 295
# Analyzing event 296
# Analyzing event 297
# Analyzing event 298
# Analyzing event 299
# Analyzing event 300
# Analyzing event 301
# Analyzing event 302
# Analyzing event 303
# Could not get stream 303
# Analyzing event 304
# Analyzing event 305
# Analyzing event 306
# Analyzing event 307
# Analyzing event 308
# Analyzing event 309
# Analyzing event 310
# Analyzing event 311
# Analyzing event 312
# Analyzing event 313
# Analyzing event 314
# Analyzing event 315
# Analyzing event 316
# Analyzing event 317
# Analyzing event 318
# Could not get stream 318
# Analyzing event 319
# Analyzing event 320
# Analyzing event 321
# Analyzing event 322
# Analyzing event 323
# Analyzing event 324
# Analyzing event 325
# Analyzing event 326
# Analyzing event 327
# Analyzing event 328
# Analyzing event 329
# Analyzing event 330
# Analyzing event 331
# Analyzing event 332
# Analyzing event 333
# Analyzing event 334
# Analyzing event 335
# Analyzing event 336
# Analyzing event 337
# Analyzing event 338
# Analyzing event 339
# Analyzing event 340
# Analyzing event 341
# Analyzing event 342
# Analyzing event 343
# Analyzing event 344
# Analyzing event 345
# Analyzing event 346
# Analyzing event 347
# Analyzing event 348
# Analyzing event 349
# Analyzing event 350
# Analyzing event 351
# Analyzing event 352
# Analyzing event 353
# Analyzing event 354
# Analyzing event 355
# Analyzing event 356
# Analyzing event 357
# Analyzing event 358
# Analyzing event 359
# Analyzing event 360
# Analyzing event 361
# Analyzing event 362
# Analyzing event 363
# Analyzing event 364
# Analyzing event 365
# Analyzing event 366
# Analyzing event 367
# Analyzing event 368
# Could not get stream 368
# Analyzing event 369
# Analyzing event 370
# Analyzing event 371
# Analyzing event 372
# Analyzing event 373
# Analyzing event 374
# Analyzing event 375
# Analyzing event 376
# Analyzing event 377
# Analyzing event 378
# Analyzing event 379
# Analyzing event 380
# Analyzing event 381
# Analyzing event 382
# Analyzing event 383
# Analyzing event 384
# Analyzing event 385
# Analyzing event 386
# Analyzing event 387
# Analyzing event 388
# Analyzing event 389
# Analyzing event 390
# Analyzing event 391
# Analyzing event 392
# Analyzing event 393
# Analyzing event 394
# Analyzing event 395
# Could not get stream 395
# Analyzing event 396
# Analyzing event 397
# Could not get stream 397
# Analyzing event 398
# Analyzing event 399
# Could not get stream 399
# Analyzing event 400
# Analyzing event 401
# Analyzing event 402
# Analyzing event 403
# Could not get stream 403
# Analyzing event 404
# Analyzing event 405
# Analyzing event 406
# Analyzing event 407
# Analyzing event 408
# Analyzing event 409
# Analyzing event 410
# Analyzing event 411
# Analyzing event 412
# Analyzing event 413
# Could not get stream 413
# Analyzing event 414
# Analyzing event 415
# Analyzing event 416
# Analyzing event 417
# Analyzing event 418
# Analyzing event 419
# Analyzing event 420
# Analyzing event 421
# Analyzing event 422
# Could not get stream 422
# Analyzing event 423
# Analyzing event 424
# Analyzing event 425
# Analyzing event 426
# Analyzing event 427
# Analyzing event 428
# Analyzing event 429
# Analyzing event 430
# Analyzing event 431
# Analyzing event 432
# Analyzing event 433
# Analyzing event 434
# Analyzing event 435
# Analyzing event 436
# Analyzing event 437
# Analyzing event 438
# Analyzing event 439
# Analyzing event 440
# Analyzing event 441
# Analyzing event 442
# Analyzing event 443
# Analyzing event 444
# Analyzing event 445
# Analyzing event 446
# Analyzing event 447
# Analyzing event 448
# Analyzing event 449
# Analyzing event 450
# Analyzing event 451
# Analyzing event 452
# Analyzing event 453
# Analyzing event 454
# Analyzing event 455
# Analyzing event 456
# Analyzing event 457
# Analyzing event 458
# Analyzing event 459
# Analyzing event 460
# Analyzing event 461
# Analyzing event 462
# Analyzing event 463
# Analyzing event 464
# Analyzing event 465
# Analyzing event 466
# Analyzing event 467
# Analyzing event 468
# Analyzing event 469
# Analyzing event 470
# Analyzing event 471
# Analyzing event 472
# Analyzing event 473
# Analyzing event 474
# Analyzing event 475
# Analyzing event 476
# Analyzing event 477
# Analyzing event 478
# Analyzing event 479
# Analyzing event 480
# Analyzing event 481
# Analyzing event 482
# Analyzing event 483
# Analyzing event 484
# Analyzing event 485
# Analyzing event 486
# Analyzing event 487
# Analyzing event 488
# Analyzing event 489
# Analyzing event 490
# Analyzing event 491
# Analyzing event 492
# Analyzing event 493
# Analyzing event 494
# Analyzing event 495
# Analyzing event 496
# Analyzing event 497
# Analyzing event 498
# Analyzing event 499
# Analyzing event 500
# Analyzing event 501
# Analyzing event 502
# Analyzing event 503
# Could not get stream 503
# Analyzing event 504
# Analyzing event 505
# Analyzing event 506
# Analyzing event 507
# Analyzing event 508
# Analyzing event 509
# Analyzing event 510
# Analyzing event 511
# Analyzing event 512
# Analyzing event 513
# Analyzing event 514
# Analyzing event 515
# Analyzing event 516
# Analyzing event 517
# Analyzing event 518
# Analyzing event 519
# Analyzing event 520
# Analyzing event 521
# Analyzing event 522
# Analyzing event 523
# Analyzing event 524
# Analyzing event 525
# Analyzing event 526
# Could not get stream 526
# Analyzing event 527
# Analyzing event 528
# Analyzing event 529
# Could not get stream 529
# Analyzing event 530
# Analyzing event 531
# Analyzing event 532
# Analyzing event 533
# Analyzing event 534
# Analyzing event 535
# Analyzing event 536
# Analyzing event 537
# Analyzing event 538
# Analyzing event 539
# Analyzing event 540
# Analyzing event 541
# Analyzing event 542
# Analyzing event 543
# Analyzing event 544
# Analyzing event 545
# Could not get stream 545
# Analyzing event 546
# Analyzing event 547
# Analyzing event 548
# Analyzing event 549
# Analyzing event 550
# Analyzing event 551
# Analyzing event 552
# Analyzing event 553
# Analyzing event 554
# Analyzing event 555
# Analyzing event 556
# Analyzing event 557
# Analyzing event 558
# Analyzing event 559
# Analyzing event 560
# Analyzing event 561
# Could not get stream 561
# Analyzing event 562
# Analyzing event 563
# Analyzing event 564
# Analyzing event 565
# Analyzing event 566
# Analyzing event 567
# Analyzing event 568
# Analyzing event 569
# Analyzing event 570
# Analyzing event 571
# Analyzing event 572
# Analyzing event 573
# Analyzing event 574
# Analyzing event 575
# Analyzing event 576
# Analyzing event 577
# Analyzing event 578
# Analyzing event 579
# Analyzing event 580
# Analyzing event 581
# Analyzing event 582
# Analyzing event 583
# Analyzing event 584
# Analyzing event 585
# Analyzing event 586
# Analyzing event 587
# Analyzing event 588
# Analyzing event 589
# Analyzing event 590
# Analyzing event 591
# Analyzing event 592
# Analyzing event 593
# Analyzing event 594
# Analyzing event 595
# Analyzing event 596
# Analyzing event 597
# Analyzing event 598
# Analyzing event 599
# Analyzing event 600
# Analyzing event 601
# Analyzing event 602
# Analyzing event 603
# Analyzing event 604
# Analyzing event 605
# Analyzing event 606
# Analyzing event 607
# Analyzing event 608
# Analyzing event 609
# Analyzing event 610
# Analyzing event 611
# Could not get stream 611
# Analyzing event 612
# Analyzing event 613
# Could not get stream 613
# Analyzing event 614
# Analyzing event 615
# Analyzing event 616
# Analyzing event 617
# Analyzing event 618
# Analyzing event 619
# Could not get stream 619
# Analyzing event 620
# Analyzing event 621
# Analyzing event 622
# Analyzing event 623
# Analyzing event 624
# Analyzing event 625
# Analyzing event 626
# Analyzing event 627
# Analyzing event 628
# Analyzing event 629
# Could not get stream 629
# Analyzing event 630
# Analyzing event 631
# Analyzing event 632
# Analyzing event 633
# Analyzing event 634
# Could not get stream 634
# Analyzing event 635
# Analyzing event 636
# Analyzing event 637
# Analyzing event 638
# Analyzing event 639
# Analyzing event 640
# Analyzing event 641
# Analyzing event 642
# Analyzing event 643
# Analyzing event 644
# Analyzing event 645
# Analyzing event 646
# Analyzing event 647
# Analyzing event 648
# Analyzing event 649
# Analyzing event 650
# Analyzing event 651
# Analyzing event 652
# Analyzing event 653
# Analyzing event 654
# Analyzing event 655
# Analyzing event 656
# Analyzing event 657
# Analyzing event 658
# Analyzing event 659
# Analyzing event 660
# Analyzing event 661
# Analyzing event 662
# Analyzing event 663
# Analyzing event 664
# Analyzing event 665
# Analyzing event 666
# Analyzing event 667
# Analyzing event 668
# Analyzing event 669
# Analyzing event 670
# Analyzing event 671
# Analyzing event 672
# Analyzing event 673
# Analyzing event 674
# Analyzing event 675
# Analyzing event 676
# Analyzing event 677
# Analyzing event 678
# Could not get stream 678
# Analyzing event 679
# Analyzing event 680
# Analyzing event 681
# Analyzing event 682
# Could not get stream 682
# Analyzing event 683
# Could not get stream 683
# Analyzing event 684
# Analyzing event 685
# Analyzing event 686
# Analyzing event 687
# Could not get stream 687
# Analyzing event 688
# Analyzing event 689
# Analyzing event 690
# Analyzing event 691
# Analyzing event 692
# Analyzing event 693
# Analyzing event 694
# Analyzing event 695
# Analyzing event 696
# Analyzing event 697

# %%
timeArrayNeg, dataArrayNeg, labelArrayNeg = stList2numpy(stListNegatives, label = 0)
timeArrayPos, dataArrayPos, labelArrayPos = stList2numpy(stListPositives, label = 1)

# %%
time  = np.concatenate([timeArrayPos , timeArrayNeg], axis = 1);
data  = np.concatenate([dataArrayPos , dataArrayNeg], axis = 1);
label = np.concatenate([labelArrayPos , labelArrayNeg]);

# %%
np.save("Time.npy", time)
np.save("Data.npy", data)
np.save("Label.npy", label)

# %%
i = 300
fig = plt.figure()
plt.plot(timeArrayNeg[:,i], dataArrayNeg[:,i])
fig = plt.figure()
plt.plot(timeArrayPos[:,i], dataArrayPos[:,i])
